# %%
# import modules
from src.util import *
from src.universe import *
from src.returns import *
from src.master_index import *
from src.text_processing import *
from src.signal_10q_def_func import *
from src.signal_10k_def_func import *
from src.signal_extraction import *
import constants as const
config = yaml.safe_load(open('config.yml'))

# init logger
init_logger()
init_notebook()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fdffd8a2fa8b> in <module>
#       8 from src.signal_10k_def_func import *
#       9 from src.signal_extraction import *
# ---> 10 import constants as const
#      11 config = yaml.safe_load(open('config.yml'))
#      12
#
# ModuleNotFoundError: No module named 'constants'

# %%
universe = Universe()
universe.get_wiki_tables()
universe.get_hist_cons()
universe.export()
# Out:
#                A    AA    AAL    AAP  AAPL   ABBV   ABC   ABT  ACAS   ACE  \
# date
# 2009-01-01  True  True  False  False  True  False  True  True  True  True
# 2009-01-02  True  True  False  False  True  False  True  True  True  True
# 2009-01-03  True  True  False  False  True  False  True  True  True  True
# 2009-01-04  True  True  False  False  True  False  True  True  True  True
# 2009-01-05  True  True  False  False  True  False  True  True  True  True
#
#               ACN  ADBE   ADI   ADM   ADP    ADS  ADSK    ADT   AEE   AEP  \
# date
# 2009-01-01  False  True  True  True  True  False  True  False  True  True
# 2009-01-02  False  True  True  True  True  False  True  False  True  True
# 2009-01-03  False  True  True  True  True  False  True  False  True  True
# 2009-01-04  False  True  True  True  True  False  True  False  True  True
# 2009-01-05  False  True  True  True  True  False  True  False  True  True
#
# ...

# %%
return_data = ReturnData()
return_data.get_price_data()
return_data.cal_returns()
return_data.export()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3a8144b8b52e> in <module>
#       1 return_data = ReturnData()
# ----> 2 return_data.get_price_data()
#       3 return_data.cal_returns()
#       4 return_data.export()
#
# c:\Users\phyun\Desktop\Data Science\Projects\10-K NLP Quant\github\NLP-10-K-10-Q-Alpha-Research\src\returns.py in get_price_data(self)
#      29         # init
#      30         quandl.ApiConfig.api_key = self.config['quandl_key']
# ---> 31         hist_cons = self.hist_cons
#      32
#      33         # download returns
#
# AttributeError: 'ReturnData' object has no attribute 'hist_cons'

# %%
master_index = MasterIndex()
master_index.get_stock_cik_map()
master_index.download_master_index()
master_index.append_full_html_link_10k()
master_index.append_full_html_link_10q()
master_index.export()
# Out:
# [2022-08-10 11:30:05] Missing CIK:
# Empty DataFrame
# Columns: [stock, start_date, end_date, cik]
# Index: []
# [2022-08-10 11:30:05] Printing stock_map
#   stock start_date   end_date         cik
# 0     A 2007-07-07 2018-03-26  0001090872
# 1    AA 2007-07-07 2016-10-31  0001675149
# 2   AAL 2013-03-24 2018-03-26  0000006201
# 3   AAP 2013-07-09 2018-03-26  0001158449
# 4  AAPL 2007-07-07 2018-03-26  0000320193
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-ecfd71ec24ca> in <module>
#       1 master_index = MasterIndex()
#       2 master_index.get_stock_cik_map()
# ----> 3 master_index.download_master_index()
#       4 master_index.append_full_html_link_10k()
#       5 master_index.append_full_html_link_10q()
#
# ...

# %%
signal_extraction = SignalExtraction()
signal_extraction.run_preparation()
signal_extraction.gen_signal_10k_all_stocks()
signal_extraction.gen_signal_10q_all_stocks()
signal_extraction.gen_8k_feats()
