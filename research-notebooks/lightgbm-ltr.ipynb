# %%
# import libraries
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
from os.path import isfile, isdir, join
import numpy as np
import pandas as pd
from datetime import datetime, date
from dateutil.relativedelta import relativedelta
from bs4 import BeautifulSoup
import re
from IPython.display import display
from zipfile import ZipFile
import pickle
import unicodedata
import pytz
from joblib import Parallel, delayed
import shutil
import difflib
import random
import math
from shutil import copyfile
import itertools
import time

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import ndcg_score

import lightgbm as lgbm
import optuna
from optuna import Trial, visualization

import matplotlib as mpl
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
# log
def log(msg):
    now = datetime.strftime(datetime.now(tz=pytz.timezone('Hongkong')), '%Y-%m-%d %H:%M:%S')
    print(f'[{now}] {msg}')
    
# pickle
def save_pkl(obj, filename):
    pickle.dump(obj, open(filename, 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
    return
def load_pkl(filename):
    return pickle.load(open(filename, 'rb'))

def get_size(path='.'):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            # skip if it is symbolic link
            if not os.path.islink(fp):
                total_size += os.path.getsize(fp)
    return total_size

def dl_txt(full_path):
    copyfile(full_path, full_path.split('/')[-1])
    print(f"Copied {full_path.split('/')[-1]}")
    return

def clear_output():
    for file in os.listdir():
        os.remove(file)
    return

fig_num = 0
def new_plot():
    global fig_num
    fig_num += 1
    plt.figure(fig_num)
    
import signal as signal_
class TimeoutException(Exception):   # Custom exception class
    pass
def timeout_handler(signum, frame):   # Custom signal handler
    raise TimeoutException
signal_.signal(signal_.SIGALRM, timeout_handler)
# Out:
# <Handlers.SIG_DFL: 0>

# %%
# params
bt_start_date = '2014-01-01' # bt - back testing
bt_end_date = '2018-03-27'
seed = 0
horizons = {'1m':21*1,'2m':21*2,'3m':21*3,'6m':21*6, '9m':21*9, '12m':21*12}
h = '12m'
n_day_horizon = int(horizons[h] * 365/252)
device_type = 'GPU'
run_hp_tune = True
n_day_sample = 4
hp_opt_hrs = 2
n_day_trn, n_day_val = 365, 30
n_day_final_predict = 10000
# early_stopping_rounds = 100

# %%
# load excess return
def load_exret(n_day):
    exret = pd.read_csv('../input/hkml-download-returns/exret.csv').assign(date = lambda x: pd.to_datetime(x.date)).set_index('date')
    exret = (1+exret).rolling(n_day).apply(np.prod, raw=True).shift(-n_day) - 1
    exret = exret \
        .unstack() \
        .loc[lambda x: x.notnull()] \
        .reset_index() \
        .rename(columns={'level_0':'stock',0:'exret'})
    log(f'Shape of exret: {exret.shape}')
    return exret


# load 10-K signals
def load_signals():
    feats_10k = pd.merge(pd.read_csv('../input/hkml-signal-extraction-10k-cpu/feats.csv'),
                     pd.read_csv('../input/hkml-signal-extraction-gpu/feats.csv'),
                     how='inner', on=['doc_id','cik','entity','filing_date','stock']) \
        .rename(columns={'filing_date':'date'}) \
        .assign(date = lambda x: pd.to_datetime(x.date),
                cik = lambda x: x.cik.astype(str).str.zfill(10)) \
        .replace([np.inf, -np.inf], np.nan)
    feat_names = [c for c in feats_10k.columns if 'feat' in c]
    feats_10k = feats_10k.rename(columns={c:c+'_10k' for c in feat_names})
    feats_10k = feats_10k.loc[:,['stock','date'] + [c for c in feats_10k.columns if 'feat' in c]]
    log(f'Shape of 10-K feats: {feats_10k.shape}')

    # load 10-Q signals
    feats_10q = pd.read_csv('../input/hkml-signal-extraction-10q-cpu/feats.csv') \
        .rename(columns={'filing_date':'date'}) \
        .assign(date = lambda x: pd.to_datetime(x.date),
                cik = lambda x: x.cik.astype(str).str.zfill(10)) \
        .replace([np.inf, -np.inf])
    feat_names = [c for c in feats_10q.columns if 'feat' in c]
    feats_10q = feats_10q.rename(columns={c:c+'_10q' for c in feat_names})
    feats_10q = feats_10q.loc[:,['stock','date'] + [c for c in feats_10q.columns if 'feat' in c]]
    log(f'Shape of 10-Q feats: {feats_10q.shape}')

    # load 8-k signal
    feats_8k = load_pkl('../input/hkml-signal-extraction-pre/feats_8k')
    log(f'Shape of 8-K feats: {feats_8k.shape}')

    # combine all signals into single df
    feats = feats_10k \
        .merge(feats_10q, how='outer', on=['stock','date']) \
        .merge(feats_8k, how='outer', on=['stock','date']) \
        .sort_values(['stock','date']) \
        .groupby('stock') \
        .apply(lambda x: x.ffill()) \
        .reset_index(drop=True)
    feat_names = [c for c in feats.columns if 'feat' in c]
    log(f'Shape of combined feats: {feats.shape}')

    # remove all nulls rows
    feats = feats.loc[lambda x: x[feat_names].notnull().sum(axis=1) > 0]
    return feats, feat_names


# merge signal and rank to build the complete dataset
def preprocess_signals(feats, exret):
    # merge with rank data    
    data = feats \
        .merge(exret, how='outer', on=['stock','date']) \
        .sort_values(['stock','date'])
    # fillna signal
    data[feat_names] = data.groupby('stock')[feat_names].ffill()
    data = data.loc[lambda x: x[feat_names].notnull().sum(axis=1) > 0]
    data[feat_names] = data[feat_names].fillna(data[feat_names].mean(axis=0))
    # derive rank of exret
    data = data.sort_values(['date','exret']).reset_index(drop=True)
    data['rank'] = data.groupby('date')['exret'].rank()
    data = data \
        .loc[lambda x: x['rank'].notnull()] \
        .sort_values(['date','rank']) \
        .drop('exret', axis=1) \
        .reset_index(drop=True)
    log(f'Shape of full dataset: {data.shape}')
    log(f'Number of nulls in full dataset: {data.isnull().sum().sum()}')
    
    # check group size distribution
    new_plot()
    data.groupby('date').size().hist(bins=50)
    plt.title('Group size distribution')

    # scaling
    data[feat_names] = StandardScaler().fit_transform(data[feat_names])
    
    # fianl sort
    data = data.sort_values(['date','rank']).reset_index(drop=True)

    # DQ
    assert data[['stock','date']].drop_duplicates().shape[0]==data.shape[0]
    print(f'Shape of data: {data.shape}')
    log(f'Total number of groups: {data.date.nunique()}')
    display(data.head())
    return data

# %%
# Function to derive training/validation start/end dates
def get_trn_val_test_dates(date, n_day_trn, n_day_val, n_day_horizon):
    date_val_end = np.datetime64(date)
    date_val_start = date_val_end + np.timedelta64(-n_day_val+1,'D')
    date_horizon_end = date_val_start + np.timedelta64(-1,'D')
    date_horizon_start = date_horizon_end + np.timedelta64(-n_day_horizon+1,'D')
    date_trn_end = date_horizon_start + np.timedelta64(-1,'D')
    date_trn_start = date_trn_end + np.timedelta64(-n_day_trn+1,'D')
    return date_trn_start, date_trn_end, date_val_start, date_val_end

def get_dataset(data, selected_feats):
    df = data.sort_values(['date','rank']).reset_index(drop=True)
    grp = df.groupby('date').size().tolist()
    qid = df['date']
    X = df[selected_feats]
    y = df['rank']
    header = df[['stock','date']]
    return X, y, grp, qid, header

def pred_score(model, X, qid):
    X_ = X.assign(date=qid)
    scores = []
    for date in X_.date.unique():
        scores += pd.Series(model.predict(X_.loc[lambda x: x.date==date].drop('date',axis=1))).tolist()
    return pd.Series(scores)

def pred_rank(model, X, qid):
    X_ = X.assign(date=qid)
    rnk = []
    for date in X_.date.unique():
        rnk += pd.Series(model.predict(X_.loc[lambda x: x.date==date].drop('date',axis=1))).rank().tolist()
    return pd.Series(rnk)

def eval_corr(rank_pred, rank_true, qid):
    df = pd.DataFrame({'rank_pred':rank_pred, 'rank_true':rank_true, 'qid':qid})
    avg_corr = df.groupby('qid').apply(lambda x: x.corr().iloc[0,1]).mean()
    return avg_corr

# %% [markdown]
# # LightGBM Ranker

# %%
'''
Function to train a model given the dataset definition, Hyperparameters, and mode
'''
def train_model(date, params, hp_tune):
    # unpack model params
    selected_feats, lgbm_var_params, lgbm_fixed_params = params
    # define dataset
    date_trn_start, date_trn_end, date_val_start, date_val_end = get_trn_val_test_dates(date, n_day_trn, n_day_val, n_day_horizon)
    X_trn, y_trn, grp_trn, qid_trn, header_trn = get_dataset(data.loc[lambda x: x.date.between(date_trn_start,date_trn_end)], selected_feats)
    X_val, y_val, grp_val, qid_val, header_val = get_dataset(data.loc[lambda x: x.date.between(date_val_start,date_val_end)], selected_feats)
    # model fit
    model = lgbm.LGBMRanker(**lgbm_fixed_params, **lgbm_var_params)
    model.fit(
        X = X_trn,
        y = y_trn,
        group = grp_trn,
        eval_set = [(X_trn, y_trn),(X_val, y_val)],
        eval_names = ['Train', 'Validation'],
        eval_group = [grp_trn, grp_val],
        eval_at = 1000,
        verbose = False,
        eval_metric = 'ndcg'
#         early_stopping_rounds = early_stopping_rounds
    )

    # output
    if hp_tune:
        model_output = -1 * model.best_score_['Validation']['ndcg@1000']
    else:
        # prediction
        pred_trn = pred_rank(model, X_trn, qid_trn)
        pred_val = pred_rank(model, X_val, qid_val)
        pred_val_out = pd.concat([header_val, pred_val], axis=1)
        # evaluation metrics
        corr_trn = pd.concat([y_trn, pred_trn], axis=1).corr().iloc[0,1]
        corr_val = pd.concat([y_val, pred_val], axis=1).corr().iloc[0,1]
        # output dict
        model_output = dict(
            date = date,
            ndcg_trn = model.evals_result_['Train']['ndcg@1000'][-1],
            ndcg_val = model.evals_result_['Validation']['ndcg@1000'][-1],
            pred_val = pred_val,
            corr_trn = corr_trn,
            corr_val = corr_val,
            evals_result_ = model.evals_result_,
            pred_val_out = pred_val_out,
            feat_imp = pd.DataFrame(list(zip(model.feature_name_, model.feature_importances_)), columns=['feat','imp']),
        )
    return model_output 


'''
Function to plot learning curves
'''
def plot_learning_curve(model_output):
    results = model_output['evals_result_']
    new_plot()
    plt.figure(figsize=(12, 4), dpi=80)
    plt.plot(results[dataset][f'ndcg@1000'])
    plt.axvline(x=model_output['best_iteration_'], color='k')
    plt.title(f'Learning Curve')
    plt.grid()
    plt.show()
    return

# %%
'''
Function to output -ve CV score given a parameter set; used for HP optimization
'''
def Objective(trial):
    feats_suggest_dict = dict(
        feats_full = ['feat_ch_full_len_10k', 'feat_ch_item_1a_len_10k', 'feat_ch_item_1b_len_10k', 'feat_ch_item_3_len_10k', 'feat_full_cos_1gram_10k', 'feat_full_cos_2gram_10k', 'feat_full_jac_1gram_10k', 'feat_full_jac_2gram_10k', 'feat_item_1a_lev_10k', 'feat_item_7_lev_10k', 'feat_lm_postive_10k', 'feat_lm_uncertainty_10k', 'feat_lm_litigious_10k', 'feat_word2vec_10k', 'feat_sen_enc_10k', 'feat_item_sentiment_10k', 'feat_fls_sentiment_10k', 'feat_ch_full_len_10q', 'feat_full_cos_1gram_10q', 'feat_full_jac_1gram_10q', 'feat_word2vec_10q', 'feat_lm_postive_10q', 'feat_cnt_8k', 'feat_cnt_8k_diff'],
        feats_subset1 = ['feat_full_jac_1gram_10q','feat_full_cos_1gram_10q','feat_word2vec_10q','feat_lm_litigious_10k','feat_ch_full_len_10k','feat_item_7_lev_10k','feat_sen_enc_10k','feat_cnt_8k','feat_ch_full_len_10q']
    )
    selected_feats = trial.suggest_categorical("selected_feats", ['feats_full','feats_subset1'])
    lgbm_var_params = dict(
        max_depth = trial.suggest_int('max_depth', 2, 32, log=True),
        num_leaves = trial.suggest_int('num_leaves', 16, 64, log=True),
        learning_rate = trial.suggest_float("learning_rate", 0.5, 3),
        objective = trial.suggest_categorical("objective", ['rank_xendcg']),
        min_split_gain = 0,
        min_child_weight = trial.suggest_float("min_child_weight", 1, 4, log=True),
        min_child_samples = trial.suggest_int('min_child_samples', 10, 80, log=True),
        subsample = trial.suggest_float("subsample", 0.5, 1),
        subsample_freq = trial.suggest_categorical("subsample_freq", [1,2,4,6,8]),
        colsample_bytree = trial.suggest_float("subsample", 0.5, 1),
        reg_alpha = trial.suggest_float("reg_alpha", 1e-5, 3, log=True),
        reg_lambda = trial.suggest_float("reg_lambda", 1e-5, 3, log=True),
        n_estimators = trial.suggest_int('n_estimators', 5, 600, log=True),
    )
    
    lgbm_fixed_params = dict(
        boosting_type = 'gbdt',
        n_jobs = -1,
        random_state = 0,
        label_gain = [i for i in range(int(data['rank'].max()) + 1)],
        device_type = device_type
    )
    
    # pack all params
    params = (feats_suggest_dict[selected_feats], lgbm_var_params, lgbm_fixed_params)
    # return average CV score
    cv_score = np.mean([train_model(date, params, hp_tune=True) for date in sampled_dates])
    return cv_score


'''
Function to run Hyperparameter Optimization
'''
def optimize_hp():
    # run optimization
    study = optuna.create_study(direction="minimize", study_name='LGBM optimization')
    study.optimize(Objective, timeout=hp_opt_hrs*60*60)
    
    # save results
    best_params = study.best_params
    best_score = study.best_value
    log(best_params)
    log(f'Highest NDCG is {-best_score}')
    trials = study.trials_dataframe()
    trials.to_csv(f'trials_{h}.csv', index=False)
    save_pkl(best_params, f'lgbm_best_params')
    save_pkl(study, f'study')
    
    # visualise relationship between parameter and CV score
    for c in trials.columns:
        if c[:7]=='params_':
            new_plot()
            trials.plot.scatter(c, 'value')
            plt.grid()
            plt.title(c)
            plt.show()
    return best_params

# %% [markdown]
# # Execution

# %%
# %%time
# prepare full dataset
feats, feat_names = load_signals()
n_day = horizons[h]
exret = load_exret(n_day)
data = preprocess_signals(feats, exret)
# Out:
# [2022-05-12 22:09:18] Shape of 10-K feats: (5219, 19)
# [2022-05-12 22:09:18] Shape of 10-Q feats: (13457, 7)
# [2022-05-12 22:09:19] Shape of 8-K feats: (1261848, 4)
# [2022-05-12 22:09:21] Shape of combined feats: (1264968, 26)
# [2022-05-12 22:09:28] Shape of exret: (910195, 3)
# [2022-05-12 22:09:32] Shape of full dataset: (861573, 27)
# [2022-05-12 22:09:32] Number of nulls in full dataset: 0
# Shape of data: (861573, 27)
# [2022-05-12 22:09:33] Total number of groups: 1944
#   stock       date  feat_ch_full_len_10k  feat_ch_item_1a_len_10k  \
# 0    GR 2009-07-06              0.377137                 0.182536
# 1   STT 2009-07-06             -0.697601                -0.827556
# 2   AKS 2009-07-06             -0.069031                 5.627883
# 3   JNS 2009-07-06             -0.168017                -0.109269
# 4   BSX 2009-07-06             -0.120595                -0.786140
#
#    feat_ch_item_1b_len_10k  feat_ch_item_3_len_10k  feat_full_cos_1gram_10k  \
# 0                -0.011572               -0.137873                -0.238267
# 1                -0.011572               -0.317092                -0.429592
# 2                -0.366215               -0.354456                 0.336221
# 3                -0.011572               -0.124473                -9.862137
# 4                -0.011572               -0.233647                 0.435220
#
#    feat_full_cos_2gram_10k  feat_full_jac_1gram_10k  feat_full_jac_2gram_10k  \
# 0                -0.206488                -0.226528                -0.102698
# 1                -0.288027                -0.611698                -1.189066
# 2                 0.198825                 0.016648                -0.097124
# 3                -7.982924                -0.111734                -0.582999
# 4                 0.423138                -0.124201                -0.459567
#
#    feat_item_1a_lev_10k  feat_item_7_lev_10k  feat_lm_postive_10k  \
# 0              0.675753             0.117764            -1.193337
# 1             -1.305595            -0.202236            -1.555274
# 2             -4.139767             0.031204            -1.291770
# 3              0.066477            -0.408841            -0.052951
# 4             -0.898175            -0.497940             0.733521
#
#    feat_lm_uncertainty_10k  feat_lm_litigious_10k  feat_word2vec_10k  \
# 0                -0.290261              -2.835392          -0.274381
# 1                 0.022803              -0.096897           0.130443
# 2                 0.386413              -1.355352           0.149674
# 3                 0.398334               0.332864           0.023753
# 4                 0.107659               1.260097           0.171292
#
#    feat_sen_enc_10k  feat_item_sentiment_10k  feat_fls_sentiment_10k  \
# 0         -0.275818                 0.249457                0.358112
# 1          0.153098                -0.712595               -1.294472
# 2          0.213952                -1.038245               -1.878321
# 3         -4.794060                -0.327306                0.838906
# 4          0.202588                 0.107110               -0.856979
#
#    feat_ch_full_len_10q  feat_full_cos_1gram_10q  feat_full_jac_1gram_10q  \
# 0             -0.474533                 0.692531                 1.206787
# 1              0.622542                -0.332395                -1.251068
# 2             -0.633473                 0.331564                -0.446710
# 3             -0.652180                -5.424688                -1.153112
# 4             -0.459294                -0.309200                -1.381531
#
#    feat_word2vec_10q  feat_lm_postive_10q  feat_cnt_8k  feat_cnt_8k_diff  rank
# 0           0.522909            -0.329535      0.32155          0.005553   1.0
# 1           0.050320             0.323795      0.32155          0.005553   2.0
# 2           0.173938            -1.611291      0.32155          0.005553   3.0
# 3          -1.569360            -1.806504      0.32155          0.005553   4.0
# 4          -0.270995             1.483207      0.32155          0.005553   5.0
# CPU times: user 12.5 s, sys: 1.86 s, total: 14.3 s
# Wall time: 15.3 s

# %%
# %%time
'''
Hyperparameter Optimization
'''
# get sampled dates for CV
s = pd.Series(data.date.unique()) \
    .loc[lambda x: x.between(x.min() + np.timedelta64(n_day_trn + n_day_horizon + n_day_val, 'D'), bt_start_date)] \
    .tolist()
sampled_dates = sorted(s[::len(s)//n_day_sample])
display(sampled_dates)

# run optimization
if run_hp_tune:
    best_params = optimize_hp()
# Out:
# [Timestamp('2011-08-05 00:00:00'),
#  Timestamp('2012-03-13 00:00:00'),
#  Timestamp('2012-10-16 00:00:00'),
#  Timestamp('2013-05-28 00:00:00'),
#  Timestamp('2013-12-31 00:00:00')]
# [I 2022-05-12 14:09:34,018] A new study created in memory with name: LGBM optimization
# [I 2022-05-12 14:09:47,334] Trial 0 finished with value: -0.87675358583549 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 12, 'num_leaves': 19, 'learning_rate': 0.8451279929163642, 'objective': 'rank_xendcg', 'min_child_weight': 2.1767584269164186, 'min_child_samples': 25, 'subsample': 0.7350618519498153, 'subsample_freq': 6, 'reg_alpha': 0.00018718341893808252, 'reg_lambda': 1.020700036264509, 'n_estimators': 73}. Best is trial 0 with value: -0.87675358583549.
# [I 2022-05-12 14:09:50,405] Trial 1 finished with value: -0.8797373167080591 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 9, 'num_leaves': 27, 'learning_rate': 1.2422686875863727, 'objective': 'rank_xendcg', 'min_child_weight': 2.8898273613958527, 'min_child_samples': 10, 'subsample': 0.9189836089517043, 'subsample_freq': 4, 'reg_alpha': 0.00046956724020952707, 'reg_lambda': 0.05364372376989927, 'n_estimators': 14}. Best is trial 1 with value: -0.8797373167080591.
# [I 2022-05-12 14:09:52,604] Trial 2 finished with value: -0.8719167063268017 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 3, 'num_leaves': 20, 'learning_rate': 0.5954626462527621, 'objective': 'rank_xendcg', 'min_child_weight': 1.5721543878869944, 'min_child_samples': 20, 'subsample': 0.9616247227202803, 'subsample_freq': 4, 'reg_alpha': 6.752783493053947e-05, 'reg_lambda': 1.0154512852008122, 'n_estimators': 8}. Best is trial 1 with value: -0.8797373167080591.
# [I 2022-05-12 14:10:01,496] Trial 3 finished with value: -0.8799090600026368 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 25, 'num_leaves': 49, 'learning_rate': 1.8944715275959665, 'objective': 'rank_xendcg', 'min_child_weight': 2.842335203633783, 'min_child_samples': 41, 'subsample': 0.8445034024254885, 'subsample_freq': 6, 'reg_alpha': 0.00023021335142368713, 'reg_lambda': 0.2620197860319898, 'n_estimators': 151}. Best is trial 3 with value: -0.8799090600026368.
# [I 2022-05-12 14:10:04,064] Trial 4 finished with value: -0.8842550382193434 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 23, 'num_leaves': 32, 'learning_rate': 1.0314108912010829, 'objective': 'rank_xendcg', 'min_child_weight': 1.750273367403878, 'min_child_samples': 18, 'subsample': 0.7975512050618702, 'subsample_freq': 1, 'reg_alpha': 0.0014306762097247728, 'reg_lambda': 0.0032996175662497926, 'n_estimators': 10}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:10:11,254] Trial 5 finished with value: -0.8715793384872358 and parameters: {'selected_feats': 'feats_full', 'max_depth': 11, 'num_leaves': 16, 'learning_rate': 2.6368708319988263, 'objective': 'rank_xendcg', 'min_child_weight': 2.671669531701228, 'min_child_samples': 35, 'subsample': 0.526590410853218, 'subsample_freq': 4, 'reg_alpha': 0.0008564713167454074, 'reg_lambda': 0.0017787921184043167, 'n_estimators': 52}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:10:22,404] Trial 6 finished with value: -0.8816113790159079 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 2, 'num_leaves': 32, 'learning_rate': 1.5138345044924781, 'objective': 'rank_xendcg', 'min_child_weight': 3.7009559698471364, 'min_child_samples': 73, 'subsample': 0.9794764609980632, 'subsample_freq': 8, 'reg_alpha': 0.2167538747635957, 'reg_lambda': 9.733469981750387e-05, 'n_estimators': 159}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:10:30,119] Trial 7 finished with value: -0.880640523386534 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 3, 'num_leaves': 31, 'learning_rate': 2.666541310500853, 'objective': 'rank_xendcg', 'min_child_weight': 1.2631954791574185, 'min_child_samples': 10, 'subsample': 0.5662367693279354, 'subsample_freq': 2, 'reg_alpha': 0.034900813190806595, 'reg_lambda': 0.0771625841442064, 'n_estimators': 93}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:10:46,011] Trial 8 finished with value: -0.8725000994419985 and parameters: {'selected_feats': 'feats_full', 'max_depth': 30, 'num_leaves': 22, 'learning_rate': 2.5798669789135498, 'objective': 'rank_xendcg', 'min_child_weight': 1.0929827453792678, 'min_child_samples': 67, 'subsample': 0.8450458488969634, 'subsample_freq': 1, 'reg_alpha': 0.0021910278226238617, 'reg_lambda': 0.7412911293001662, 'n_estimators': 254}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:10:50,399] Trial 9 finished with value: -0.8763769343302009 and parameters: {'selected_feats': 'feats_full', 'max_depth': 5, 'num_leaves': 27, 'learning_rate': 2.197425077820584, 'objective': 'rank_xendcg', 'min_child_weight': 1.5344168665437834, 'min_child_samples': 21, 'subsample': 0.7863198246808683, 'subsample_freq': 8, 'reg_alpha': 0.019886850902884935, 'reg_lambda': 5.36002858958676e-05, 'n_estimators': 32}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:10:53,437] Trial 10 finished with value: -0.8760165431808096 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 17, 'num_leaves': 50, 'learning_rate': 1.1322242717375193, 'objective': 'rank_xendcg', 'min_child_weight': 1.7966372554110337, 'min_child_samples': 15, 'subsample': 0.6752915326886098, 'subsample_freq': 1, 'reg_alpha': 1.3927857005003822e-05, 'reg_lambda': 0.003045915242895059, 'n_estimators': 21}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:11:21,534] Trial 11 finished with value: -0.8801667411500407 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 2, 'num_leaves': 39, 'learning_rate': 1.4631048848809276, 'objective': 'rank_xendcg', 'min_child_weight': 3.7808876760164996, 'min_child_samples': 79, 'subsample': 0.9778916717417214, 'subsample_freq': 8, 'reg_alpha': 1.2711978393843202, 'reg_lambda': 8.206383590408724e-05, 'n_estimators': 568}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:11:23,899] Trial 12 finished with value: -0.8788054732536548 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 5, 'num_leaves': 36, 'learning_rate': 1.6372960312071858, 'objective': 'rank_xendcg', 'min_child_weight': 3.876304110011444, 'min_child_samples': 44, 'subsample': 0.6944790952711457, 'subsample_freq': 8, 'reg_alpha': 0.4290332124557998, 'reg_lambda': 0.00039147132885219494, 'n_estimators': 8}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:11:39,581] Trial 13 finished with value: -0.8775831474731971 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 2, 'num_leaves': 41, 'learning_rate': 0.9824855842522102, 'objective': 'rank_xendcg', 'min_child_weight': 2.273075171027312, 'min_child_samples': 16, 'subsample': 0.8974811537313223, 'subsample_freq': 1, 'reg_alpha': 0.12427993263672495, 'reg_lambda': 1.1207769225102687e-05, 'n_estimators': 281}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:11:44,367] Trial 14 finished with value: -0.8765614459319352 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 6, 'num_leaves': 29, 'learning_rate': 1.955543139225727, 'objective': 'rank_xendcg', 'min_child_weight': 1.8271982703670215, 'min_child_samples': 53, 'subsample': 0.6249274503156386, 'subsample_freq': 2, 'reg_alpha': 0.005668738111651741, 'reg_lambda': 0.008717915307697815, 'n_estimators': 26}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:11:47,717] Trial 15 finished with value: -0.8766877132214883 and parameters: {'selected_feats': 'feats_full', 'max_depth': 18, 'num_leaves': 63, 'learning_rate': 1.441461617720887, 'objective': 'rank_xendcg', 'min_child_weight': 3.288391637516217, 'min_child_samples': 33, 'subsample': 0.799022023402124, 'subsample_freq': 8, 'reg_alpha': 0.014685877093863169, 'reg_lambda': 0.0004436677554853266, 'n_estimators': 5}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:11:55,327] Trial 16 finished with value: -0.862462821310219 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 3, 'num_leaves': 24, 'learning_rate': 2.2241342441512595, 'objective': 'rank_xendcg', 'min_child_weight': 1.357114248195034, 'min_child_samples': 14, 'subsample': 0.9004419953954813, 'subsample_freq': 1, 'reg_alpha': 0.12214230177752963, 'reg_lambda': 0.014119699644326003, 'n_estimators': 134}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:12:20,150] Trial 17 finished with value: -0.8735737451170159 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 8, 'num_leaves': 33, 'learning_rate': 0.5272847230738118, 'objective': 'rank_xendcg', 'min_child_weight': 2.4240400363026624, 'min_child_samples': 27, 'subsample': 0.9996911964241353, 'subsample_freq': 8, 'reg_alpha': 1.3560252813146172, 'reg_lambda': 0.00047888555528175164, 'n_estimators': 462}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:12:26,097] Trial 18 finished with value: -0.8813625880594234 and parameters: {'selected_feats': 'feats_full', 'max_depth': 4, 'num_leaves': 41, 'learning_rate': 0.8733735818301882, 'objective': 'rank_xendcg', 'min_child_weight': 1.946437725752471, 'min_child_samples': 58, 'subsample': 0.8075953535099071, 'subsample_freq': 1, 'reg_alpha': 0.0034264978714994188, 'reg_lambda': 1.1917380812598158e-05, 'n_estimators': 47}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:12:43,435] Trial 19 finished with value: -0.8767966675522659 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 17, 'num_leaves': 49, 'learning_rate': 2.951594206567616, 'objective': 'rank_xendcg', 'min_child_weight': 1.0019270002386966, 'min_child_samples': 21, 'subsample': 0.7279085568964687, 'subsample_freq': 2, 'reg_alpha': 4.5672004347094786e-05, 'reg_lambda': 6.752845770094727e-05, 'n_estimators': 208}. Best is trial 4 with value: -0.8842550382193434.
# [I 2022-05-12 14:12:46,392] Trial 20 finished with value: -0.8857447480152116 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 23, 'num_leaves': 34, 'learning_rate': 1.6008407773756184, 'objective': 'rank_xendcg', 'min_child_weight': 3.325407226248201, 'min_child_samples': 32, 'subsample': 0.6320800943724683, 'subsample_freq': 6, 'reg_alpha': 0.08789947687932442, 'reg_lambda': 0.0012899241849310382, 'n_estimators': 14}. Best is trial 20 with value: -0.8857447480152116.
# [I 2022-05-12 14:12:48,937] Trial 21 finished with value: -0.881679566819181 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 23, 'num_leaves': 34, 'learning_rate': 1.4212392207718088, 'objective': 'rank_xendcg', 'min_child_weight': 3.43638696808732, 'min_child_samples': 13, 'subsample': 0.6371706447997769, 'subsample_freq': 6, 'reg_alpha': 0.10531610965893681, 'reg_lambda': 0.001024146646515629, 'n_estimators': 12}. Best is trial 20 with value: -0.8857447480152116.
# [I 2022-05-12 14:12:52,532] Trial 22 finished with value: -0.8802305599013897 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 24, 'num_leaves': 36, 'learning_rate': 1.2460075118609724, 'objective': 'rank_xendcg', 'min_child_weight': 3.196998363811026, 'min_child_samples': 12, 'subsample': 0.6267220963697394, 'subsample_freq': 6, 'reg_alpha': 0.05954985232112238, 'reg_lambda': 0.0019152417356964404, 'n_estimators': 14}. Best is trial 20 with value: -0.8857447480152116.
# [I 2022-05-12 14:12:55,080] Trial 23 finished with value: -0.884195621605641 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 22, 'num_leaves': 25, 'learning_rate': 1.7642082515373823, 'objective': 'rank_xendcg', 'min_child_weight': 3.3035518833496273, 'min_child_samples': 18, 'subsample': 0.6143428636692261, 'subsample_freq': 6, 'reg_alpha': 0.00690493790727199, 'reg_lambda': 0.020234286627231056, 'n_estimators': 13}. Best is trial 20 with value: -0.8857447480152116.
# [I 2022-05-12 14:12:57,467] Trial 24 finished with value: -0.8870116842874578 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 32, 'num_leaves': 25, 'learning_rate': 1.8093228745303729, 'objective': 'rank_xendcg', 'min_child_weight': 2.5828432706113515, 'min_child_samples': 18, 'subsample': 0.5644678019624862, 'subsample_freq': 6, 'reg_alpha': 0.012972088913036995, 'reg_lambda': 0.02555107573368417, 'n_estimators': 5}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:12:59,518] Trial 25 finished with value: -0.8753300748841989 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 30, 'num_leaves': 23, 'learning_rate': 2.207957500219848, 'objective': 'rank_xendcg', 'min_child_weight': 2.552655116482773, 'min_child_samples': 25, 'subsample': 0.5006383897262341, 'subsample_freq': 6, 'reg_alpha': 0.0012371123680627813, 'reg_lambda': 0.005748618450709946, 'n_estimators': 5}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:02,985] Trial 26 finished with value: -0.8777808760732798 and parameters: {'selected_feats': 'feats_full', 'max_depth': 13, 'num_leaves': 27, 'learning_rate': 1.9557646087087865, 'objective': 'rank_xendcg', 'min_child_weight': 2.0347345347667876, 'min_child_samples': 32, 'subsample': 0.5704586414657548, 'subsample_freq': 6, 'reg_alpha': 0.01389181015060194, 'reg_lambda': 0.02919049409938799, 'n_estimators': 8}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:05,212] Trial 27 finished with value: -0.8801610611996814 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 31, 'num_leaves': 20, 'learning_rate': 1.695320120975441, 'objective': 'rank_xendcg', 'min_child_weight': 2.9260678889887335, 'min_child_samples': 18, 'subsample': 0.5512609812945867, 'subsample_freq': 6, 'reg_alpha': 0.30869538443343986, 'reg_lambda': 0.22897519207060646, 'n_estimators': 7}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:08,429] Trial 28 finished with value: -0.8851946015967005 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 15, 'num_leaves': 30, 'learning_rate': 1.0876802747984153, 'objective': 'rank_xendcg', 'min_child_weight': 1.6541007145690967, 'min_child_samples': 30, 'subsample': 0.6785627532741053, 'subsample_freq': 1, 'reg_alpha': 0.03539177400130974, 'reg_lambda': 0.0036713381239566276, 'n_estimators': 20}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:11,654] Trial 29 finished with value: -0.8722081261858705 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 13, 'num_leaves': 18, 'learning_rate': 0.6779626739186, 'objective': 'rank_xendcg', 'min_child_weight': 2.189893214976751, 'min_child_samples': 24, 'subsample': 0.6778844761152647, 'subsample_freq': 6, 'reg_alpha': 2.9499551702123457, 'reg_lambda': 0.15472203499673198, 'n_estimators': 19}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:15,598] Trial 30 finished with value: -0.8735656311417316 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 16, 'num_leaves': 45, 'learning_rate': 1.2846506552072556, 'objective': 'rank_xendcg', 'min_child_weight': 2.326132071672231, 'min_child_samples': 29, 'subsample': 0.7238130608063229, 'subsample_freq': 6, 'reg_alpha': 0.02327408199823227, 'reg_lambda': 0.009408565472087883, 'n_estimators': 35}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:17,941] Trial 31 finished with value: -0.8773742926287517 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 20, 'num_leaves': 30, 'learning_rate': 1.0701906897521456, 'objective': 'rank_xendcg', 'min_child_weight': 1.6382207573571026, 'min_child_samples': 23, 'subsample': 0.6535797051040586, 'subsample_freq': 1, 'reg_alpha': 0.050383070937595205, 'reg_lambda': 0.0032029897157609937, 'n_estimators': 10}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:21,520] Trial 32 finished with value: -0.8805033170523021 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 10, 'num_leaves': 28, 'learning_rate': 0.7929207982963753, 'objective': 'rank_xendcg', 'min_child_weight': 1.732962233488401, 'min_child_samples': 44, 'subsample': 0.6007093112776407, 'subsample_freq': 1, 'reg_alpha': 0.01068766140415783, 'reg_lambda': 0.04187189226748697, 'n_estimators': 19}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:23,913] Trial 33 finished with value: -0.8820733180425426 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 25, 'num_leaves': 25, 'learning_rate': 0.8322648387194156, 'objective': 'rank_xendcg', 'min_child_weight': 2.0451385326951863, 'min_child_samples': 38, 'subsample': 0.7666420976201629, 'subsample_freq': 1, 'reg_alpha': 0.0022886844747300066, 'reg_lambda': 0.0009518801045807012, 'n_estimators': 6}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:27,532] Trial 34 finished with value: -0.87986495624624 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 14, 'num_leaves': 36, 'learning_rate': 1.3031053471291822, 'objective': 'rank_xendcg', 'min_child_weight': 1.4488296527414246, 'min_child_samples': 28, 'subsample': 0.5915647337211579, 'subsample_freq': 4, 'reg_alpha': 0.000345564851304562, 'reg_lambda': 0.004088092099212466, 'n_estimators': 17}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:29,999] Trial 35 finished with value: -0.8804200020270839 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 27, 'num_leaves': 21, 'learning_rate': 1.8242780767063995, 'objective': 'rank_xendcg', 'min_child_weight': 2.7065715945501214, 'min_child_samples': 18, 'subsample': 0.6970082304172351, 'subsample_freq': 1, 'reg_alpha': 0.0009522983636167463, 'reg_lambda': 0.09704520257213359, 'n_estimators': 10}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:32,585] Trial 36 finished with value: -0.875093275417982 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 20, 'num_leaves': 26, 'learning_rate': 1.5991976735986624, 'objective': 'rank_xendcg', 'min_child_weight': 2.9796589135391853, 'min_child_samples': 36, 'subsample': 0.7529095720323381, 'subsample_freq': 4, 'reg_alpha': 0.0001114794362432369, 'reg_lambda': 2.2431744014649184, 'n_estimators': 10}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:34,695] Trial 37 finished with value: -0.8764955015561853 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 15, 'num_leaves': 30, 'learning_rate': 2.091901576151052, 'objective': 'rank_xendcg', 'min_child_weight': 1.3085312357123846, 'min_child_samples': 31, 'subsample': 0.839847009717978, 'subsample_freq': 6, 'reg_alpha': 0.03792453620001725, 'reg_lambda': 0.00018249558436010655, 'n_estimators': 6}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:40,852] Trial 38 finished with value: -0.8837621731622791 and parameters: {'selected_feats': 'feats_full', 'max_depth': 32, 'num_leaves': 18, 'learning_rate': 1.1011828685050788, 'objective': 'rank_xendcg', 'min_child_weight': 1.1807351020995025, 'min_child_samples': 12, 'subsample': 0.5289404690423047, 'subsample_freq': 1, 'reg_alpha': 0.0004943958425742543, 'reg_lambda': 0.001340540797787598, 'n_estimators': 60}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:44,710] Trial 39 finished with value: -0.8809453289124981 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 11, 'num_leaves': 32, 'learning_rate': 1.0059601196137702, 'objective': 'rank_xendcg', 'min_child_weight': 1.6371237587773135, 'min_child_samples': 16, 'subsample': 0.7164473351178842, 'subsample_freq': 2, 'reg_alpha': 0.004050714972188993, 'reg_lambda': 0.011660335158218155, 'n_estimators': 28}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:47,961] Trial 40 finished with value: -0.8721851686297262 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 20, 'num_leaves': 39, 'learning_rate': 0.6355602114762173, 'objective': 'rank_xendcg', 'min_child_weight': 1.4354786248033709, 'min_child_samples': 22, 'subsample': 0.5834007842557871, 'subsample_freq': 4, 'reg_alpha': 0.06612389181415446, 'reg_lambda': 0.0002132005645198447, 'n_estimators': 15}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:50,462] Trial 41 finished with value: -0.8799889219805485 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 22, 'num_leaves': 25, 'learning_rate': 1.7042159033666158, 'objective': 'rank_xendcg', 'min_child_weight': 3.4637878773654713, 'min_child_samples': 19, 'subsample': 0.6074800393257421, 'subsample_freq': 6, 'reg_alpha': 0.008364885821206118, 'reg_lambda': 0.02213149029059213, 'n_estimators': 12}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:53,881] Trial 42 finished with value: -0.8715509538670151 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 27, 'num_leaves': 23, 'learning_rate': 1.7995661126610705, 'objective': 'rank_xendcg', 'min_child_weight': 3.17351515523778, 'min_child_samples': 18, 'subsample': 0.6525134060739092, 'subsample_freq': 6, 'reg_alpha': 0.026391242308143596, 'reg_lambda': 0.052798229499538045, 'n_estimators': 22}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:13:57,451] Trial 43 finished with value: -0.8824776647401864 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 20, 'num_leaves': 28, 'learning_rate': 2.4741716014506707, 'objective': 'rank_xendcg', 'min_child_weight': 3.6548576035527702, 'min_child_samples': 26, 'subsample': 0.5339862164942408, 'subsample_freq': 6, 'reg_alpha': 0.005921612597986361, 'reg_lambda': 0.006820117821700772, 'n_estimators': 38}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:00,427] Trial 44 finished with value: -0.8781268881302863 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 27, 'num_leaves': 31, 'learning_rate': 1.5502700324427825, 'objective': 'rank_xendcg', 'min_child_weight': 2.595875128669289, 'min_child_samples': 10, 'subsample': 0.6578347428038579, 'subsample_freq': 6, 'reg_alpha': 0.0025863143886023883, 'reg_lambda': 0.019062241478143605, 'n_estimators': 7}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:03,078] Trial 45 finished with value: -0.8778199332368221 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 22, 'num_leaves': 34, 'learning_rate': 2.0380383013375, 'objective': 'rank_xendcg', 'min_child_weight': 2.9978538641205335, 'min_child_samples': 16, 'subsample': 0.5584328444587119, 'subsample_freq': 1, 'reg_alpha': 0.0015832162359596834, 'reg_lambda': 0.002451924082005674, 'n_estimators': 12}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:10,236] Trial 46 finished with value: -0.8823999096188452 and parameters: {'selected_feats': 'feats_full', 'max_depth': 18, 'num_leaves': 26, 'learning_rate': 1.412379574555552, 'objective': 'rank_xendcg', 'min_child_weight': 1.9459378444379265, 'min_child_samples': 20, 'subsample': 0.6128454756684508, 'subsample_freq': 6, 'reg_alpha': 0.5132537182240041, 'reg_lambda': 0.42288013284727527, 'n_estimators': 83}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:12,897] Trial 47 finished with value: -0.8810731613790006 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 8, 'num_leaves': 29, 'learning_rate': 1.1795459150331087, 'objective': 'rank_xendcg', 'min_child_weight': 3.9184984299845182, 'min_child_samples': 38, 'subsample': 0.7019458129637446, 'subsample_freq': 1, 'reg_alpha': 0.19452093265756762, 'reg_lambda': 0.0007190948718383363, 'n_estimators': 16}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:16,160] Trial 48 finished with value: -0.8749659506912307 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 27, 'num_leaves': 21, 'learning_rate': 2.3521806069105855, 'objective': 'rank_xendcg', 'min_child_weight': 1.8389798191307682, 'min_child_samples': 48, 'subsample': 0.8272112704122211, 'subsample_freq': 6, 'reg_alpha': 0.008518598268105942, 'reg_lambda': 0.005146574044540483, 'n_estimators': 25}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:18,595] Trial 49 finished with value: -0.8776895450184725 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 12, 'num_leaves': 24, 'learning_rate': 1.828065243465324, 'objective': 'rank_xendcg', 'min_child_weight': 1.5754411389303482, 'min_child_samples': 14, 'subsample': 0.8767471542007359, 'subsample_freq': 2, 'reg_alpha': 0.0006491874366374548, 'reg_lambda': 0.09363012169285326, 'n_estimators': 9}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:22,047] Trial 50 finished with value: -0.8778205159089015 and parameters: {'selected_feats': 'feats_full', 'max_depth': 15, 'num_leaves': 37, 'learning_rate': 0.9469037190173389, 'objective': 'rank_xendcg', 'min_child_weight': 2.711023056155118, 'min_child_samples': 11, 'subsample': 0.7579167255448973, 'subsample_freq': 1, 'reg_alpha': 0.016074311068031796, 'reg_lambda': 0.03834917873212164, 'n_estimators': 6}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:28,641] Trial 51 finished with value: -0.8846308917232036 and parameters: {'selected_feats': 'feats_full', 'max_depth': 31, 'num_leaves': 16, 'learning_rate': 1.1304628788832656, 'objective': 'rank_xendcg', 'min_child_weight': 2.469724370671488, 'min_child_samples': 30, 'subsample': 0.5136509949471731, 'subsample_freq': 1, 'reg_alpha': 0.0003569884709826279, 'reg_lambda': 0.0015053209251141883, 'n_estimators': 52}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:36,202] Trial 52 finished with value: -0.8831809265581168 and parameters: {'selected_feats': 'feats_full', 'max_depth': 29, 'num_leaves': 16, 'learning_rate': 1.363043461142731, 'objective': 'rank_xendcg', 'min_child_weight': 2.458930880155108, 'min_child_samples': 29, 'subsample': 0.5119410704741968, 'subsample_freq': 1, 'reg_alpha': 0.00023234602300595242, 'reg_lambda': 0.0017399314863615078, 'n_estimators': 59}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:43,979] Trial 53 finished with value: -0.8847872438931278 and parameters: {'selected_feats': 'feats_full', 'max_depth': 24, 'num_leaves': 17, 'learning_rate': 1.573389270635765, 'objective': 'rank_xendcg', 'min_child_weight': 2.8090011693507697, 'min_child_samples': 33, 'subsample': 0.5446299524399809, 'subsample_freq': 1, 'reg_alpha': 9.994927054962524e-05, 'reg_lambda': 0.0006418411911186906, 'n_estimators': 101}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:50,215] Trial 54 finished with value: -0.8827058218122626 and parameters: {'selected_feats': 'feats_full', 'max_depth': 32, 'num_leaves': 17, 'learning_rate': 0.7416443145002858, 'objective': 'rank_xendcg', 'min_child_weight': 2.85821530260074, 'min_child_samples': 33, 'subsample': 0.5421057937404221, 'subsample_freq': 1, 'reg_alpha': 3.301755170871921e-05, 'reg_lambda': 0.000278269122122529, 'n_estimators': 42}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:14:58,606] Trial 55 finished with value: -0.8843922775114981 and parameters: {'selected_feats': 'feats_full', 'max_depth': 25, 'num_leaves': 17, 'learning_rate': 1.5099089346777588, 'objective': 'rank_xendcg', 'min_child_weight': 2.192147871677769, 'min_child_samples': 42, 'subsample': 0.5676375614931899, 'subsample_freq': 1, 'reg_alpha': 0.00010583739356044953, 'reg_lambda': 0.0006492177098184422, 'n_estimators': 103}. Best is trial 24 with value: -0.8870116842874578.
# [I 2022-05-12 14:15:07,769] Trial 56 finished with value: -0.8914651688294842 and parameters: {'selected_feats': 'feats_full', 'max_depth': 25, 'num_leaves': 17, 'learning_rate': 1.5183972888606627, 'objective': 'rank_xendcg', 'min_child_weight': 2.1422621787694367, 'min_child_samples': 43, 'subsample': 0.5751488396574196, 'subsample_freq': 1, 'reg_alpha': 9.542254432564763e-05, 'reg_lambda': 0.0006241991193499569, 'n_estimators': 116}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:15:17,631] Trial 57 finished with value: -0.8783100218449466 and parameters: {'selected_feats': 'feats_full', 'max_depth': 18, 'num_leaves': 19, 'learning_rate': 1.6099492185487196, 'objective': 'rank_xendcg', 'min_child_weight': 2.352031846117839, 'min_child_samples': 49, 'subsample': 0.5078954218645892, 'subsample_freq': 1, 'reg_alpha': 1.3304345818778043e-05, 'reg_lambda': 0.0003626191164845393, 'n_estimators': 130}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:15:25,309] Trial 58 finished with value: -0.883562637479231 and parameters: {'selected_feats': 'feats_full', 'max_depth': 24, 'num_leaves': 17, 'learning_rate': 1.180554967021822, 'objective': 'rank_xendcg', 'min_child_weight': 2.462870407174964, 'min_child_samples': 35, 'subsample': 0.5806545307080907, 'subsample_freq': 1, 'reg_alpha': 3.642607960427562e-05, 'reg_lambda': 0.000140723156081166, 'n_estimators': 74}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:15:33,454] Trial 59 finished with value: -0.8812263952504983 and parameters: {'selected_feats': 'feats_full', 'max_depth': 28, 'num_leaves': 19, 'learning_rate': 1.920705622295953, 'objective': 'rank_xendcg', 'min_child_weight': 2.089125085171956, 'min_child_samples': 30, 'subsample': 0.5215588099608437, 'subsample_freq': 8, 'reg_alpha': 2.3371138858860486e-05, 'reg_lambda': 3.552124517916178e-05, 'n_estimators': 111}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:15:46,223] Trial 60 finished with value: -0.8709348551898485 and parameters: {'selected_feats': 'feats_full', 'max_depth': 6, 'num_leaves': 16, 'learning_rate': 1.3586302275968498, 'objective': 'rank_xendcg', 'min_child_weight': 2.594734028150439, 'min_child_samples': 39, 'subsample': 0.543351857634461, 'subsample_freq': 1, 'reg_alpha': 7.586405771663108e-05, 'reg_lambda': 0.0012677464119540782, 'n_estimators': 186}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:15:54,175] Trial 61 finished with value: -0.8832011850294197 and parameters: {'selected_feats': 'feats_full', 'max_depth': 25, 'num_leaves': 17, 'learning_rate': 1.4641773205137023, 'objective': 'rank_xendcg', 'min_child_weight': 2.1848687176338673, 'min_child_samples': 41, 'subsample': 0.5671610447014688, 'subsample_freq': 1, 'reg_alpha': 0.000121791395347477, 'reg_lambda': 0.0005935381448760213, 'n_estimators': 95}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:16:02,385] Trial 62 finished with value: -0.8837409202016634 and parameters: {'selected_feats': 'feats_full', 'max_depth': 32, 'num_leaves': 18, 'learning_rate': 1.6984756843051685, 'objective': 'rank_xendcg', 'min_child_weight': 2.769172203279783, 'min_child_samples': 43, 'subsample': 0.6339311603551464, 'subsample_freq': 1, 'reg_alpha': 0.0001673919181073462, 'reg_lambda': 0.0021882919523745375, 'n_estimators': 109}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:16:08,666] Trial 63 finished with value: -0.8838562739468431 and parameters: {'selected_feats': 'feats_full', 'max_depth': 21, 'num_leaves': 16, 'learning_rate': 1.5171418015813323, 'objective': 'rank_xendcg', 'min_child_weight': 2.199674152513988, 'min_child_samples': 64, 'subsample': 0.5588266883916517, 'subsample_freq': 1, 'reg_alpha': 5.539932658876636e-05, 'reg_lambda': 0.0008405531714478508, 'n_estimators': 56}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:16:20,191] Trial 64 finished with value: -0.8758195594663807 and parameters: {'selected_feats': 'feats_full', 'max_depth': 24, 'num_leaves': 19, 'learning_rate': 1.5207134137590481, 'objective': 'rank_xendcg', 'min_child_weight': 3.063958369762324, 'min_child_samples': 34, 'subsample': 0.5920714124481683, 'subsample_freq': 1, 'reg_alpha': 0.0002814824535066576, 'reg_lambda': 0.0005373208751021125, 'n_estimators': 158}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:16:38,606] Trial 65 finished with value: -0.8853443967657464 and parameters: {'selected_feats': 'feats_full', 'max_depth': 26, 'num_leaves': 20, 'learning_rate': 0.9282710656947822, 'objective': 'rank_xendcg', 'min_child_weight': 1.8861195923800023, 'min_child_samples': 49, 'subsample': 0.576073254364593, 'subsample_freq': 1, 'reg_alpha': 0.00010421733722871252, 'reg_lambda': 0.0015184629744034656, 'n_estimators': 276}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:16:53,469] Trial 66 finished with value: -0.8796913292006387 and parameters: {'selected_feats': 'feats_full', 'max_depth': 29, 'num_leaves': 20, 'learning_rate': 0.9337185497512271, 'objective': 'rank_xendcg', 'min_child_weight': 1.7406296550391949, 'min_child_samples': 55, 'subsample': 0.6694724209999386, 'subsample_freq': 1, 'reg_alpha': 1.844389072903119e-05, 'reg_lambda': 0.0035579870922321536, 'n_estimators': 226}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:17:33,509] Trial 67 finished with value: -0.8752111621863076 and parameters: {'selected_feats': 'feats_full', 'max_depth': 18, 'num_leaves': 21, 'learning_rate': 0.535530179718031, 'objective': 'rank_xendcg', 'min_child_weight': 1.9014399720325812, 'min_child_samples': 48, 'subsample': 0.619784716197091, 'subsample_freq': 8, 'reg_alpha': 0.08363786189792284, 'reg_lambda': 0.00030626317727826214, 'n_estimators': 364}. Best is trial 56 with value: -0.8914651688294842.
# [I 2022-05-12 14:17:55,414] Trial 68 finished with value: -0.8925196350115543 and parameters: {'selected_feats': 'feats_full', 'max_depth': 16, 'num_leaves': 57, 'learning_rate': 1.1978169972935138, 'objective': 'rank_xendcg', 'min_child_weight': 2.3369768021831296, 'min_child_samples': 27, 'subsample': 0.5169367134077609, 'subsample_freq': 2, 'reg_alpha': 6.839432917205142e-05, 'reg_lambda': 0.001466009282461263, 'n_estimators': 294}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:18:30,749] Trial 69 finished with value: -0.8819467690504865 and parameters: {'selected_feats': 'feats_full', 'max_depth': 16, 'num_leaves': 62, 'learning_rate': 0.8857918693483738, 'objective': 'rank_xendcg', 'min_child_weight': 2.3517871348766075, 'min_child_samples': 63, 'subsample': 0.5785665442550696, 'subsample_freq': 2, 'reg_alpha': 6.58964709999406e-05, 'reg_lambda': 0.0025571391554546803, 'n_estimators': 287}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:19:09,653] Trial 70 finished with value: -0.8704510442915978 and parameters: {'selected_feats': 'feats_full', 'max_depth': 19, 'num_leaves': 58, 'learning_rate': 1.2624890185473583, 'objective': 'rank_xendcg', 'min_child_weight': 2.050144012278083, 'min_child_samples': 24, 'subsample': 0.6002739384122605, 'subsample_freq': 2, 'reg_alpha': 0.00018314651795825032, 'reg_lambda': 0.007613000212039316, 'n_estimators': 574}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:19:41,232] Trial 71 finished with value: -0.883158503655275 and parameters: {'selected_feats': 'feats_full', 'max_depth': 23, 'num_leaves': 22, 'learning_rate': 1.1657281599593814, 'objective': 'rank_xendcg', 'min_child_weight': 2.5282466788794107, 'min_child_samples': 31, 'subsample': 0.5152731073663582, 'subsample_freq': 2, 'reg_alpha': 8.485983521937234e-05, 'reg_lambda': 0.0012028521458585712, 'n_estimators': 388}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:20:15,158] Trial 72 finished with value: -0.886841014117854 and parameters: {'selected_feats': 'feats_full', 'max_depth': 29, 'num_leaves': 53, 'learning_rate': 1.0952280365858489, 'objective': 'rank_xendcg', 'min_child_weight': 2.80985966556969, 'min_child_samples': 27, 'subsample': 0.5496019906828316, 'subsample_freq': 2, 'reg_alpha': 0.00040327083149161103, 'reg_lambda': 0.0015809764618745495, 'n_estimators': 356}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:20:53,823] Trial 73 finished with value: -0.8785117039870347 and parameters: {'selected_feats': 'feats_full', 'max_depth': 26, 'num_leaves': 55, 'learning_rate': 0.9954901943488333, 'objective': 'rank_xendcg', 'min_child_weight': 3.4014503176925235, 'min_child_samples': 27, 'subsample': 0.5514437941591281, 'subsample_freq': 2, 'reg_alpha': 0.00014490445003938418, 'reg_lambda': 0.0039625227323307685, 'n_estimators': 320}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:21:12,843] Trial 74 finished with value: -0.8774357000573201 and parameters: {'selected_feats': 'feats_full', 'max_depth': 22, 'num_leaves': 52, 'learning_rate': 1.3372773958584179, 'objective': 'rank_xendcg', 'min_child_weight': 2.781889742133545, 'min_child_samples': 36, 'subsample': 0.5319915558031978, 'subsample_freq': 2, 'reg_alpha': 0.03818106490027643, 'reg_lambda': 0.00498351298492392, 'n_estimators': 193}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:21:47,909] Trial 75 finished with value: -0.8838163046196709 and parameters: {'selected_feats': 'feats_full', 'max_depth': 16, 'num_leaves': 43, 'learning_rate': 1.665846400769326, 'objective': 'rank_xendcg', 'min_child_weight': 2.2810879652935445, 'min_child_samples': 26, 'subsample': 0.6372187994404627, 'subsample_freq': 2, 'reg_alpha': 1.0069568402582764e-05, 'reg_lambda': 0.0018745004482139157, 'n_estimators': 498}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:22:02,830] Trial 76 finished with value: -0.8813146931743105 and parameters: {'selected_feats': 'feats_full', 'max_depth': 30, 'num_leaves': 47, 'learning_rate': 1.059449662336389, 'objective': 'rank_xendcg', 'min_child_weight': 1.6656144702180402, 'min_child_samples': 52, 'subsample': 0.5930660666624935, 'subsample_freq': 4, 'reg_alpha': 3.983892381368346e-05, 'reg_lambda': 0.0010604929296406495, 'n_estimators': 261}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:22:36,571] Trial 77 finished with value: -0.8871918467051296 and parameters: {'selected_feats': 'feats_full', 'max_depth': 9, 'num_leaves': 58, 'learning_rate': 1.2263292778963395, 'objective': 'rank_xendcg', 'min_child_weight': 2.6436001615765803, 'min_child_samples': 24, 'subsample': 0.531128932782611, 'subsample_freq': 2, 'reg_alpha': 2.733151012230657e-05, 'reg_lambda': 0.012534382210721746, 'n_estimators': 459}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:23:07,261] Trial 78 finished with value: -0.88561002699736 and parameters: {'selected_feats': 'feats_full', 'max_depth': 11, 'num_leaves': 58, 'learning_rate': 1.21931258408366, 'objective': 'rank_xendcg', 'min_child_weight': 2.0983312852931326, 'min_child_samples': 22, 'subsample': 0.5744046701648284, 'subsample_freq': 2, 'reg_alpha': 2.490730513128732e-05, 'reg_lambda': 0.0029552462229156047, 'n_estimators': 419}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:23:38,776] Trial 79 finished with value: -0.8864054527726608 and parameters: {'selected_feats': 'feats_full', 'max_depth': 9, 'num_leaves': 60, 'learning_rate': 1.1815290068860544, 'objective': 'rank_xendcg', 'min_child_weight': 2.1360708397833195, 'min_child_samples': 22, 'subsample': 0.5753050884317662, 'subsample_freq': 2, 'reg_alpha': 2.400986936505203e-05, 'reg_lambda': 0.010505931701039802, 'n_estimators': 443}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:24:10,767] Trial 80 finished with value: -0.8799202831556651 and parameters: {'selected_feats': 'feats_full', 'max_depth': 9, 'num_leaves': 60, 'learning_rate': 1.234569951175072, 'objective': 'rank_xendcg', 'min_child_weight': 2.1310065982317528, 'min_child_samples': 22, 'subsample': 0.5316090838772637, 'subsample_freq': 2, 'reg_alpha': 2.3828555874514824e-05, 'reg_lambda': 0.012666589502960266, 'n_estimators': 462}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:24:35,622] Trial 81 finished with value: -0.8822206323803364 and parameters: {'selected_feats': 'feats_full', 'max_depth': 9, 'num_leaves': 55, 'learning_rate': 1.1899433225092906, 'objective': 'rank_xendcg', 'min_child_weight': 1.9756844730902214, 'min_child_samples': 20, 'subsample': 0.5726733997450294, 'subsample_freq': 2, 'reg_alpha': 2.5036143557709925e-05, 'reg_lambda': 0.010267700203168063, 'n_estimators': 399}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:24:59,838] Trial 82 finished with value: -0.8757358156121067 and parameters: {'selected_feats': 'feats_full', 'max_depth': 7, 'num_leaves': 64, 'learning_rate': 1.4059827282833697, 'objective': 'rank_xendcg', 'min_child_weight': 1.8614195643867353, 'min_child_samples': 24, 'subsample': 0.555162103714636, 'subsample_freq': 2, 'reg_alpha': 1.6690229494884025e-05, 'reg_lambda': 0.017219584728901557, 'n_estimators': 297}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:25:22,461] Trial 83 finished with value: -0.8795579728474493 and parameters: {'selected_feats': 'feats_full', 'max_depth': 10, 'num_leaves': 56, 'learning_rate': 1.244013199276614, 'objective': 'rank_xendcg', 'min_child_weight': 2.274171537540555, 'min_child_samples': 21, 'subsample': 0.9430381145360769, 'subsample_freq': 2, 'reg_alpha': 5.389826300458723e-05, 'reg_lambda': 0.02999827556815134, 'n_estimators': 345}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:25:58,404] Trial 84 finished with value: -0.886508434446404 and parameters: {'selected_feats': 'feats_full', 'max_depth': 8, 'num_leaves': 50, 'learning_rate': 1.0448132219318846, 'objective': 'rank_xendcg', 'min_child_weight': 2.6318893373607013, 'min_child_samples': 17, 'subsample': 0.5839642910197281, 'subsample_freq': 2, 'reg_alpha': 2.937202863090293e-05, 'reg_lambda': 0.002571070766968135, 'n_estimators': 431}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:26:36,820] Trial 85 finished with value: -0.8815311066668162 and parameters: {'selected_feats': 'feats_full', 'max_depth': 8, 'num_leaves': 52, 'learning_rate': 1.0506955641142168, 'objective': 'rank_xendcg', 'min_child_weight': 2.6131590659864234, 'min_child_samples': 17, 'subsample': 0.5005071076443407, 'subsample_freq': 2, 'reg_alpha': 3.315657114582202e-05, 'reg_lambda': 0.005856073766356971, 'n_estimators': 443}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:27:07,291] Trial 86 finished with value: -0.8828872745031264 and parameters: {'selected_feats': 'feats_full', 'max_depth': 7, 'num_leaves': 59, 'learning_rate': 1.758965677346268, 'objective': 'rank_xendcg', 'min_child_weight': 2.378112655861851, 'min_child_samples': 19, 'subsample': 0.6054437010356662, 'subsample_freq': 2, 'reg_alpha': 2.700044947165088e-05, 'reg_lambda': 0.0026027748941808955, 'n_estimators': 503}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:27:37,631] Trial 87 finished with value: -0.8829906380358155 and parameters: {'selected_feats': 'feats_full', 'max_depth': 12, 'num_leaves': 53, 'learning_rate': 1.300841169994215, 'objective': 'rank_xendcg', 'min_child_weight': 3.1189248857582905, 'min_child_samples': 23, 'subsample': 0.5383262307317724, 'subsample_freq': 2, 'reg_alpha': 1.21701776958733e-05, 'reg_lambda': 0.008524739923769606, 'n_estimators': 409}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:27:58,070] Trial 88 finished with value: -0.8885101272195097 and parameters: {'selected_feats': 'feats_full', 'max_depth': 10, 'num_leaves': 47, 'learning_rate': 1.128174991240507, 'objective': 'rank_xendcg', 'min_child_weight': 2.910193907103072, 'min_child_samples': 15, 'subsample': 0.5835029400748543, 'subsample_freq': 2, 'reg_alpha': 1.770051543073919e-05, 'reg_lambda': 0.06791677210311654, 'n_estimators': 243}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:28:19,845] Trial 89 finished with value: -0.8892077265087008 and parameters: {'selected_feats': 'feats_full', 'max_depth': 6, 'num_leaves': 49, 'learning_rate': 1.0963484007469497, 'objective': 'rank_xendcg', 'min_child_weight': 2.6802274909066917, 'min_child_samples': 15, 'subsample': 0.5888550558999889, 'subsample_freq': 2, 'reg_alpha': 1.7264718749260605e-05, 'reg_lambda': 0.16807100279705614, 'n_estimators': 218}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:28:45,888] Trial 90 finished with value: -0.8801045679461514 and parameters: {'selected_feats': 'feats_full', 'max_depth': 6, 'num_leaves': 48, 'learning_rate': 0.8005261475886989, 'objective': 'rank_xendcg', 'min_child_weight': 2.9388967929463172, 'min_child_samples': 15, 'subsample': 0.5880358710196694, 'subsample_freq': 2, 'reg_alpha': 1.8134475275002137e-05, 'reg_lambda': 0.17964052233488245, 'n_estimators': 211}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:29:07,653] Trial 91 finished with value: -0.8863164314297365 and parameters: {'selected_feats': 'feats_full', 'max_depth': 4, 'num_leaves': 46, 'learning_rate': 1.1410143448709789, 'objective': 'rank_xendcg', 'min_child_weight': 2.627531095988585, 'min_child_samples': 17, 'subsample': 0.5602495704746989, 'subsample_freq': 2, 'reg_alpha': 4.6088838472741226e-05, 'reg_lambda': 0.33678745035233587, 'n_estimators': 234}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:29:27,713] Trial 92 finished with value: -0.8801535245157694 and parameters: {'selected_feats': 'feats_full', 'max_depth': 4, 'num_leaves': 46, 'learning_rate': 1.0905837596332917, 'objective': 'rank_xendcg', 'min_child_weight': 2.6988791174677025, 'min_child_samples': 17, 'subsample': 0.5610418939847301, 'subsample_freq': 2, 'reg_alpha': 5.137734736336464e-05, 'reg_lambda': 0.3999566114410966, 'n_estimators': 235}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:30:01,671] Trial 93 finished with value: -0.8813036596357074 and parameters: {'selected_feats': 'feats_full', 'max_depth': 5, 'num_leaves': 50, 'learning_rate': 1.1473240898958657, 'objective': 'rank_xendcg', 'min_child_weight': 2.532920865692641, 'min_child_samples': 14, 'subsample': 0.5246013157219437, 'subsample_freq': 2, 'reg_alpha': 1.0261875977278524e-05, 'reg_lambda': 1.089561181486633, 'n_estimators': 330}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:30:49,576] Trial 94 finished with value: -0.8870045514544616 and parameters: {'selected_feats': 'feats_full', 'max_depth': 4, 'num_leaves': 43, 'learning_rate': 1.0032982361990372, 'objective': 'rank_xendcg', 'min_child_weight': 2.8600485531081157, 'min_child_samples': 15, 'subsample': 0.5508193042927314, 'subsample_freq': 2, 'reg_alpha': 1.670593908029028e-05, 'reg_lambda': 0.06299106226770033, 'n_estimators': 533}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:31:37,438] Trial 95 finished with value: -0.8808029227832112 and parameters: {'selected_feats': 'feats_full', 'max_depth': 3, 'num_leaves': 50, 'learning_rate': 1.0285812603934417, 'objective': 'rank_xendcg', 'min_child_weight': 3.034101626280566, 'min_child_samples': 15, 'subsample': 0.5469585407430823, 'subsample_freq': 2, 'reg_alpha': 1.632088532472534e-05, 'reg_lambda': 0.12034351062660036, 'n_estimators': 524}. Best is trial 68 with value: -0.8925196350115543.
# [I 2022-05-12 14:32:52,774] Trial 96 finished with value: -0.8768452695127757 and parameters: {'selected_feats': 'feats_full', 'max_depth': 9, 'num_leaves': 42, 'learning_rate': 0.8953866066323163, 'objective': 'rank_xendcg', 'min_child_weight': 2.8635012022154434, 'min_child_samples': 13, 'subsample': 0.5236379775317328, 'subsample_freq': 2, 'reg_alpha': 3.1746653652921256e-05, 'reg_lambda': 0.06412706175761486, 'n_estimators': 588}. Best is trial 68 with value: -0.8925196350115543.
# ...
# [I 2022-05-12 16:03:38,509] Trial 482 finished with value: -0.8791732654201851 and parameters: {'selected_feats': 'feats_full', 'max_depth': 23, 'num_leaves': 61, 'learning_rate': 1.0518007635349083, 'objective': 'rank_xendcg', 'min_child_weight': 3.3877270533804094, 'min_child_samples': 29, 'subsample': 0.6735992071582068, 'subsample_freq': 2, 'reg_alpha': 0.0003356418708480533, 'reg_lambda': 0.0003086882443156159, 'n_estimators': 81}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:03:46,221] Trial 483 finished with value: -0.880545336296047 and parameters: {'selected_feats': 'feats_full', 'max_depth': 22, 'num_leaves': 17, 'learning_rate': 1.0896513620400972, 'objective': 'rank_xendcg', 'min_child_weight': 3.081529835712721, 'min_child_samples': 10, 'subsample': 0.6970560178148688, 'subsample_freq': 2, 'reg_alpha': 0.00025750623569410444, 'reg_lambda': 0.0004123199082551739, 'n_estimators': 45}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:03:59,657] Trial 484 finished with value: -0.8853069280055383 and parameters: {'selected_feats': 'feats_full', 'max_depth': 14, 'num_leaves': 60, 'learning_rate': 1.1144109228810855, 'objective': 'rank_xendcg', 'min_child_weight': 3.2833545201462218, 'min_child_samples': 29, 'subsample': 0.6689445428917533, 'subsample_freq': 2, 'reg_alpha': 0.0002189468172525607, 'reg_lambda': 0.0008159955701907785, 'n_estimators': 120}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:04:19,256] Trial 485 finished with value: -0.8769023127243429 and parameters: {'selected_feats': 'feats_full', 'max_depth': 20, 'num_leaves': 63, 'learning_rate': 0.594381907352826, 'objective': 'rank_xendcg', 'min_child_weight': 3.1338152476783514, 'min_child_samples': 24, 'subsample': 0.6756013614001131, 'subsample_freq': 2, 'reg_alpha': 0.00014934977231322272, 'reg_lambda': 0.0005004751855330941, 'n_estimators': 109}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:04:26,197] Trial 486 finished with value: -0.8844575122164388 and parameters: {'selected_feats': 'feats_full', 'max_depth': 23, 'num_leaves': 57, 'learning_rate': 1.2139168015620538, 'objective': 'rank_xendcg', 'min_child_weight': 2.9390480901561564, 'min_child_samples': 27, 'subsample': 0.6863684811286612, 'subsample_freq': 2, 'reg_alpha': 0.00010788114579608875, 'reg_lambda': 0.0006277009091524454, 'n_estimators': 37}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:04:39,163] Trial 487 finished with value: -0.8855410350990407 and parameters: {'selected_feats': 'feats_full', 'max_depth': 21, 'num_leaves': 24, 'learning_rate': 1.1749355011253457, 'objective': 'rank_xendcg', 'min_child_weight': 3.1784330127462637, 'min_child_samples': 25, 'subsample': 0.6264961276010454, 'subsample_freq': 2, 'reg_alpha': 5.1806173322784854e-05, 'reg_lambda': 0.007594041670985032, 'n_estimators': 127}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:04:50,626] Trial 488 finished with value: -0.8821980665917796 and parameters: {'selected_feats': 'feats_full', 'max_depth': 24, 'num_leaves': 35, 'learning_rate': 1.115741072664819, 'objective': 'rank_xendcg', 'min_child_weight': 3.3848897227517787, 'min_child_samples': 27, 'subsample': 0.6521769327423457, 'subsample_freq': 2, 'reg_alpha': 0.00017307100823558218, 'reg_lambda': 0.0021986138701945777, 'n_estimators': 90}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:05:05,071] Trial 489 finished with value: -0.8800887301030869 and parameters: {'selected_feats': 'feats_full', 'max_depth': 25, 'num_leaves': 62, 'learning_rate': 1.286195249321777, 'objective': 'rank_xendcg', 'min_child_weight': 3.033442054431157, 'min_child_samples': 25, 'subsample': 0.5686541261986102, 'subsample_freq': 6, 'reg_alpha': 0.00012189509296518252, 'reg_lambda': 0.0034174218530199207, 'n_estimators': 248}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:05:19,857] Trial 490 finished with value: -0.8825815474880254 and parameters: {'selected_feats': 'feats_full', 'max_depth': 23, 'num_leaves': 30, 'learning_rate': 2.1111503009380432, 'objective': 'rank_xendcg', 'min_child_weight': 2.264019637773191, 'min_child_samples': 28, 'subsample': 0.579712758555371, 'subsample_freq': 1, 'reg_alpha': 2.095541209036964e-05, 'reg_lambda': 0.00018617511003306348, 'n_estimators': 223}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:05:33,204] Trial 491 finished with value: -0.8870635953229208 and parameters: {'selected_feats': 'feats_full', 'max_depth': 32, 'num_leaves': 33, 'learning_rate': 1.216111078196999, 'objective': 'rank_xendcg', 'min_child_weight': 3.2809242070115876, 'min_child_samples': 23, 'subsample': 0.6116259422030855, 'subsample_freq': 2, 'reg_alpha': 3.4530989895270195e-05, 'reg_lambda': 0.0009953381688307314, 'n_estimators': 119}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:05:37,184] Trial 492 finished with value: -0.8786263193376188 and parameters: {'selected_feats': 'feats_full', 'max_depth': 18, 'num_leaves': 59, 'learning_rate': 2.4950550342840634, 'objective': 'rank_xendcg', 'min_child_weight': 3.21568518127235, 'min_child_samples': 26, 'subsample': 0.5892811546598746, 'subsample_freq': 2, 'reg_alpha': 0.0006097792893481485, 'reg_lambda': 0.0004428050205185883, 'n_estimators': 13}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:05:44,328] Trial 493 finished with value: -0.8830300705077935 and parameters: {'selected_feats': 'feats_full', 'max_depth': 25, 'num_leaves': 60, 'learning_rate': 1.0617258430275847, 'objective': 'rank_xendcg', 'min_child_weight': 3.0877923018673945, 'min_child_samples': 26, 'subsample': 0.6798914984487008, 'subsample_freq': 6, 'reg_alpha': 7.447251136619452e-05, 'reg_lambda': 0.013969498522886566, 'n_estimators': 53}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:05:53,540] Trial 494 finished with value: -0.8876157832468641 and parameters: {'selected_feats': 'feats_full', 'max_depth': 2, 'num_leaves': 57, 'learning_rate': 1.2641838946890422, 'objective': 'rank_xendcg', 'min_child_weight': 2.8919116671295244, 'min_child_samples': 14, 'subsample': 0.5494238153815126, 'subsample_freq': 1, 'reg_alpha': 0.00023897215595483547, 'reg_lambda': 0.00033327064949875744, 'n_estimators': 105}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:05:56,929] Trial 495 finished with value: -0.8869989430709019 and parameters: {'selected_feats': 'feats_full', 'max_depth': 28, 'num_leaves': 17, 'learning_rate': 1.3164135643282417, 'objective': 'rank_xendcg', 'min_child_weight': 3.365957359636656, 'min_child_samples': 44, 'subsample': 0.6289668090445286, 'subsample_freq': 2, 'reg_alpha': 4.897161169411626e-05, 'reg_lambda': 0.0007460534614583083, 'n_estimators': 5}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:06:07,030] Trial 496 finished with value: -0.8794373053509045 and parameters: {'selected_feats': 'feats_subset1', 'max_depth': 15, 'num_leaves': 61, 'learning_rate': 2.2117561269082553, 'objective': 'rank_xendcg', 'min_child_weight': 3.4588312538459993, 'min_child_samples': 35, 'subsample': 0.6491221652735936, 'subsample_freq': 2, 'reg_alpha': 2.700218256334309e-05, 'reg_lambda': 0.0005190265780116593, 'n_estimators': 135}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:06:25,636] Trial 497 finished with value: -0.8710381435825048 and parameters: {'selected_feats': 'feats_full', 'max_depth': 3, 'num_leaves': 18, 'learning_rate': 1.2426044796142934, 'objective': 'rank_xendcg', 'min_child_weight': 2.9843971428400042, 'min_child_samples': 24, 'subsample': 0.665923567443919, 'subsample_freq': 6, 'reg_alpha': 8.848815863303189e-05, 'reg_lambda': 0.0006497845089468942, 'n_estimators': 235}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:06:34,801] Trial 498 finished with value: -0.8863856069693474 and parameters: {'selected_feats': 'feats_full', 'max_depth': 5, 'num_leaves': 55, 'learning_rate': 1.1521533175321583, 'objective': 'rank_xendcg', 'min_child_weight': 2.02155715669554, 'min_child_samples': 42, 'subsample': 0.6171790961577022, 'subsample_freq': 1, 'reg_alpha': 0.0004087248605107302, 'reg_lambda': 0.23406798117419994, 'n_estimators': 114}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:06:51,957] Trial 499 finished with value: -0.8836685742416138 and parameters: {'selected_feats': 'feats_full', 'max_depth': 22, 'num_leaves': 59, 'learning_rate': 1.3566625944711423, 'objective': 'rank_xendcg', 'min_child_weight': 2.345225367645198, 'min_child_samples': 30, 'subsample': 0.5946870123022893, 'subsample_freq': 2, 'reg_alpha': 0.00015095008080552095, 'reg_lambda': 0.0014947175640150105, 'n_estimators': 209}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:07:05,422] Trial 500 finished with value: -0.8804016118885096 and parameters: {'selected_feats': 'feats_full', 'max_depth': 30, 'num_leaves': 63, 'learning_rate': 1.290886793287586, 'objective': 'rank_xendcg', 'min_child_weight': 3.20657359010747, 'min_child_samples': 23, 'subsample': 0.6054708944885452, 'subsample_freq': 2, 'reg_alpha': 0.2910174904417278, 'reg_lambda': 0.0003983313511508826, 'n_estimators': 132}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:07:14,113] Trial 501 finished with value: -0.88566968450918 and parameters: {'selected_feats': 'feats_full', 'max_depth': 27, 'num_leaves': 57, 'learning_rate': 1.2332678969292798, 'objective': 'rank_xendcg', 'min_child_weight': 3.325266430924027, 'min_child_samples': 47, 'subsample': 0.6375301714704359, 'subsample_freq': 6, 'reg_alpha': 0.7069070317573886, 'reg_lambda': 0.0009790236685748848, 'n_estimators': 101}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:07:29,911] Trial 502 finished with value: -0.8907172830588121 and parameters: {'selected_feats': 'feats_full', 'max_depth': 21, 'num_leaves': 59, 'learning_rate': 1.1965533496441172, 'objective': 'rank_xendcg', 'min_child_weight': 3.0831785480850677, 'min_child_samples': 13, 'subsample': 0.5796308067148238, 'subsample_freq': 2, 'reg_alpha': 4.0487217229565526e-05, 'reg_lambda': 0.32590470013200906, 'n_estimators': 143}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:07:47,288] Trial 503 finished with value: -0.8696685205466151 and parameters: {'selected_feats': 'feats_full', 'max_depth': 19, 'num_leaves': 61, 'learning_rate': 1.109868185572428, 'objective': 'rank_xendcg', 'min_child_weight': 3.069215506857563, 'min_child_samples': 13, 'subsample': 0.5577134799860448, 'subsample_freq': 2, 'reg_alpha': 3.3451033655790566e-05, 'reg_lambda': 0.25455702409131997, 'n_estimators': 148}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:07:57,027] Trial 504 finished with value: -0.885849204583543 and parameters: {'selected_feats': 'feats_full', 'max_depth': 16, 'num_leaves': 64, 'learning_rate': 1.1719175417987615, 'objective': 'rank_xendcg', 'min_child_weight': 3.1657695704790783, 'min_child_samples': 12, 'subsample': 0.56996875986539, 'subsample_freq': 2, 'reg_alpha': 4.029667072982512e-05, 'reg_lambda': 0.3484205993641278, 'n_estimators': 67}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:08:06,922] Trial 505 finished with value: -0.8846839813455489 and parameters: {'selected_feats': 'feats_full', 'max_depth': 20, 'num_leaves': 59, 'learning_rate': 1.186916165138451, 'objective': 'rank_xendcg', 'min_child_weight': 2.977532771317515, 'min_child_samples': 13, 'subsample': 0.579960283124109, 'subsample_freq': 2, 'reg_alpha': 2.5783681515318856e-05, 'reg_lambda': 0.17574208341968403, 'n_estimators': 81}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:08:24,251] Trial 506 finished with value: -0.8794144000253092 and parameters: {'selected_feats': 'feats_full', 'max_depth': 21, 'num_leaves': 62, 'learning_rate': 1.2093952766675267, 'objective': 'rank_xendcg', 'min_child_weight': 3.059580149157903, 'min_child_samples': 14, 'subsample': 0.5733315020974507, 'subsample_freq': 2, 'reg_alpha': 5.143600918199752e-05, 'reg_lambda': 0.000610399805089991, 'n_estimators': 199}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:08:44,862] Trial 507 finished with value: -0.8820231151027954 and parameters: {'selected_feats': 'feats_full', 'max_depth': 22, 'num_leaves': 60, 'learning_rate': 0.9762916835193512, 'objective': 'rank_xendcg', 'min_child_weight': 3.1207130196868826, 'min_child_samples': 14, 'subsample': 0.5899360346782923, 'subsample_freq': 2, 'reg_alpha': 3.779357227844519e-05, 'reg_lambda': 0.20692916484246238, 'n_estimators': 127}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:08:54,793] Trial 508 finished with value: -0.8800630863573474 and parameters: {'selected_feats': 'feats_full', 'max_depth': 21, 'num_leaves': 58, 'learning_rate': 1.1373460796579218, 'objective': 'rank_xendcg', 'min_child_weight': 1.6918040879112903, 'min_child_samples': 12, 'subsample': 0.5803340011852454, 'subsample_freq': 2, 'reg_alpha': 6.408503636018039e-05, 'reg_lambda': 0.003064853507262727, 'n_estimators': 94}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:09:08,199] Trial 509 finished with value: -0.8919908343931733 and parameters: {'selected_feats': 'feats_full', 'max_depth': 20, 'num_leaves': 61, 'learning_rate': 1.25718890890743, 'objective': 'rank_xendcg', 'min_child_weight': 2.896876837280536, 'min_child_samples': 64, 'subsample': 0.5835365268980119, 'subsample_freq': 2, 'reg_alpha': 2.1392546915277753e-05, 'reg_lambda': 0.3172990095319661, 'n_estimators': 113}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:09:12,448] Trial 510 finished with value: -0.8865327942078551 and parameters: {'selected_feats': 'feats_full', 'max_depth': 17, 'num_leaves': 62, 'learning_rate': 1.2837429539919993, 'objective': 'rank_xendcg', 'min_child_weight': 2.889942743567266, 'min_child_samples': 75, 'subsample': 0.5698798390019498, 'subsample_freq': 2, 'reg_alpha': 1.874619335753186e-05, 'reg_lambda': 0.28924118357865086, 'n_estimators': 9}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:09:22,362] Trial 511 finished with value: -0.8831239486724485 and parameters: {'selected_feats': 'feats_full', 'max_depth': 19, 'num_leaves': 59, 'learning_rate': 1.3309658008195495, 'objective': 'rank_xendcg', 'min_child_weight': 2.8796439811369123, 'min_child_samples': 72, 'subsample': 0.5817472028612681, 'subsample_freq': 1, 'reg_alpha': 2.3773214620924237e-05, 'reg_lambda': 0.33364167740240785, 'n_estimators': 109}. Best is trial 168 with value: -0.8968834618408532.
# [I 2022-05-12 16:09:45,861] Trial 512 finished with value: -0.8790552383279169 and parameters: {'selected_feats': 'feats_full', 'max_depth': 20, 'num_leaves': 40, 'learning_rate': 1.0525220215723772, 'objective': 'rank_xendcg', 'min_child_weight': 2.9567422390133467, 'min_child_samples': 79, 'subsample': 0.5607048747719815, 'subsample_freq': 2, 'reg_alpha': 1.906897697502976e-05, 'reg_lambda': 0.19380711613400273, 'n_estimators': 216}. Best is trial 168 with value: -0.8968834618408532.
# [2022-05-13 00:09:45] {'selected_feats': 'feats_full', 'max_depth': 7, 'num_leaves': 60, 'learning_rate': 2.2927845836957332, 'objective': 'rank_xendcg', 'min_child_weight': 2.930102155179201, 'min_child_samples': 15, 'subsample': 0.6755053022966739, 'subsample_freq': 6, 'reg_alpha': 0.008044478600171353, 'reg_lambda': 0.08152456169952542, 'n_estimators': 281}
# [2022-05-13 00:09:45] Highest NDCG is 0.8968834618408532
# CPU times: user 3h 30min 14s, sys: 11min 11s, total: 3h 41min 26s
# Wall time: 2h 14s

# %%
# %%time
'''
Fit model (with best params) for all dates
'''
# hard-code the best params if not running HP tuning here
if run_hp_tune==False:
    best_params = {'selected_feats': 'feats_subset1', 'sample_weight_p': 1.3887048885948596, 'max_depth': 10, 'num_leaves': 54, 'learning_rate': 0.1537015325324695, 'objective': 'lambdarank', 'min_child_weight': 3.3478798601563096, 'min_child_samples': 16, 'subsample': 0.5725379109999287, 'subsample_freq': 8, 'reg_alpha': 0.5445575343281451, 'reg_lambda': 0.21693106623962125}
# setup best params
lgbm_fixed_params = dict(
    boosting_type = 'gbdt',
    n_jobs = -1,
    random_state = 0,
    label_gain = [i for i in range(int(data['rank'].max()) + 1)],
    device_type = device_type
)
feats_suggest_dict = dict(
    feats_full = ['feat_ch_full_len_10k', 'feat_ch_item_1a_len_10k', 'feat_ch_item_1b_len_10k', 'feat_ch_item_3_len_10k', 'feat_full_cos_1gram_10k', 'feat_full_cos_2gram_10k', 'feat_full_jac_1gram_10k', 'feat_full_jac_2gram_10k', 'feat_item_1a_lev_10k', 'feat_item_7_lev_10k', 'feat_lm_postive_10k', 'feat_lm_uncertainty_10k', 'feat_lm_litigious_10k', 'feat_word2vec_10k', 'feat_sen_enc_10k', 'feat_item_sentiment_10k', 'feat_fls_sentiment_10k', 'feat_ch_full_len_10q', 'feat_full_cos_1gram_10q', 'feat_full_jac_1gram_10q', 'feat_word2vec_10q', 'feat_lm_postive_10q', 'feat_cnt_8k', 'feat_cnt_8k_diff'],
    feats_subset1 = ['feat_full_jac_1gram_10q','feat_full_cos_1gram_10q','feat_word2vec_10q','feat_lm_litigious_10k','feat_ch_full_len_10k','feat_item_7_lev_10k','feat_sen_enc_10k','feat_cnt_8k','feat_ch_full_len_10q']
)
params = (feats_suggest_dict[best_params['selected_feats']], 
          {x:best_params[x] for x in list(best_params) if x not in ['selected_feats']}, 
          lgbm_fixed_params)

# get full list of dates
date_list = pd.Series(data.date.unique()) \
        .loc[lambda x: x.between(x.min() + np.timedelta64(n_day_trn + n_day_horizon + n_day_val, 'D'), x.max())]
n_group = (date_list.max() - date_list.min()) / np.timedelta64(1,'D') / n_day_val
n_group = math.ceil(n_group + 1 + 1e-5)
date_list = pd.Series([date_list.min() + np.timedelta64(i * n_day_val,'D') for i in range(n_group)])
date_list = date_list[date_list.apply(lambda d: data.loc[lambda x: x.date.between(d + np.timedelta64(-n_day_val+1,'D'), d)].shape[0]) > 0]
date_list = date_list.tolist()
log(f'Total number of days to train model: {len(date_list)}')

# generate outputs for all dates
model_outputs = []
for date in date_list[:n_day_final_predict]:
    model_outputs.append(train_model(date, params, hp_tune=False))
    log(f'Completed model training for date {date}')
# Out:
# [2022-05-13 00:09:49] Total number of days to train model: 70
# [2022-05-13 00:09:53] Completed model training for date 2011-08-05 00:00:00
# [2022-05-13 00:09:57] Completed model training for date 2011-09-04 00:00:00
# [2022-05-13 00:10:01] Completed model training for date 2011-10-04 00:00:00
# [2022-05-13 00:10:06] Completed model training for date 2011-11-03 00:00:00
# [2022-05-13 00:10:10] Completed model training for date 2011-12-03 00:00:00
# [2022-05-13 00:10:14] Completed model training for date 2012-01-02 00:00:00
# [2022-05-13 00:10:18] Completed model training for date 2012-02-01 00:00:00
# [2022-05-13 00:10:23] Completed model training for date 2012-03-02 00:00:00
# [2022-05-13 00:10:29] Completed model training for date 2012-04-01 00:00:00
# [2022-05-13 00:10:34] Completed model training for date 2012-05-01 00:00:00
# [2022-05-13 00:10:38] Completed model training for date 2012-05-31 00:00:00
# [2022-05-13 00:10:43] Completed model training for date 2012-06-30 00:00:00
# [2022-05-13 00:10:46] Completed model training for date 2012-07-30 00:00:00
# [2022-05-13 00:10:52] Completed model training for date 2012-08-29 00:00:00
# [2022-05-13 00:10:56] Completed model training for date 2012-09-28 00:00:00
# [2022-05-13 00:11:00] Completed model training for date 2012-10-28 00:00:00
# [2022-05-13 00:11:04] Completed model training for date 2012-11-27 00:00:00
# [2022-05-13 00:11:09] Completed model training for date 2012-12-27 00:00:00
# [2022-05-13 00:11:13] Completed model training for date 2013-01-26 00:00:00
# [2022-05-13 00:11:17] Completed model training for date 2013-02-25 00:00:00
# [2022-05-13 00:11:22] Completed model training for date 2013-03-27 00:00:00
# [2022-05-13 00:11:29] Completed model training for date 2013-04-26 00:00:00
# [2022-05-13 00:11:33] Completed model training for date 2013-05-26 00:00:00
# [2022-05-13 00:11:41] Completed model training for date 2013-06-25 00:00:00
# [2022-05-13 00:11:45] Completed model training for date 2013-07-25 00:00:00
# [2022-05-13 00:11:49] Completed model training for date 2013-08-24 00:00:00
# [2022-05-13 00:11:53] Completed model training for date 2013-09-23 00:00:00
# [2022-05-13 00:11:57] Completed model training for date 2013-10-23 00:00:00
# [2022-05-13 00:12:01] Completed model training for date 2013-11-22 00:00:00
# [2022-05-13 00:12:05] Completed model training for date 2013-12-22 00:00:00
# [2022-05-13 00:12:13] Completed model training for date 2014-01-21 00:00:00
# [2022-05-13 00:12:17] Completed model training for date 2014-02-20 00:00:00
# [2022-05-13 00:12:21] Completed model training for date 2014-03-22 00:00:00
# [2022-05-13 00:12:28] Completed model training for date 2014-04-21 00:00:00
# [2022-05-13 00:12:32] Completed model training for date 2014-05-21 00:00:00
# [2022-05-13 00:12:39] Completed model training for date 2014-06-20 00:00:00
# [2022-05-13 00:12:44] Completed model training for date 2014-07-20 00:00:00
# [2022-05-13 00:12:48] Completed model training for date 2014-08-19 00:00:00
# [2022-05-13 00:12:54] Completed model training for date 2014-09-18 00:00:00
# [2022-05-13 00:12:59] Completed model training for date 2014-10-18 00:00:00
# [2022-05-13 00:13:05] Completed model training for date 2014-11-17 00:00:00
# [2022-05-13 00:13:12] Completed model training for date 2014-12-17 00:00:00
# [2022-05-13 00:13:17] Completed model training for date 2015-01-16 00:00:00
# [2022-05-13 00:13:21] Completed model training for date 2015-02-15 00:00:00
# [2022-05-13 00:13:27] Completed model training for date 2015-03-17 00:00:00
# [2022-05-13 00:13:31] Completed model training for date 2015-04-16 00:00:00
# [2022-05-13 00:13:35] Completed model training for date 2015-05-16 00:00:00
# [2022-05-13 00:13:39] Completed model training for date 2015-06-15 00:00:00
# [2022-05-13 00:13:43] Completed model training for date 2015-07-15 00:00:00
# [2022-05-13 00:13:51] Completed model training for date 2015-08-14 00:00:00
# [2022-05-13 00:13:58] Completed model training for date 2015-09-13 00:00:00
# [2022-05-13 00:14:02] Completed model training for date 2015-10-13 00:00:00
# [2022-05-13 00:14:06] Completed model training for date 2015-11-12 00:00:00
# [2022-05-13 00:14:10] Completed model training for date 2015-12-12 00:00:00
# [2022-05-13 00:14:14] Completed model training for date 2016-01-11 00:00:00
# [2022-05-13 00:14:19] Completed model training for date 2016-02-10 00:00:00
# [2022-05-13 00:14:24] Completed model training for date 2016-03-11 00:00:00
# [2022-05-13 00:14:28] Completed model training for date 2016-04-10 00:00:00
# [2022-05-13 00:14:33] Completed model training for date 2016-05-10 00:00:00
# [2022-05-13 00:14:37] Completed model training for date 2016-06-09 00:00:00
# [2022-05-13 00:14:41] Completed model training for date 2016-07-09 00:00:00
# [2022-05-13 00:14:45] Completed model training for date 2016-08-08 00:00:00
# [2022-05-13 00:14:49] Completed model training for date 2016-09-07 00:00:00
# [2022-05-13 00:14:54] Completed model training for date 2016-10-07 00:00:00
# [2022-05-13 00:14:59] Completed model training for date 2016-11-06 00:00:00
# [2022-05-13 00:15:03] Completed model training for date 2016-12-06 00:00:00
# [2022-05-13 00:15:07] Completed model training for date 2017-01-05 00:00:00
# [2022-05-13 00:15:14] Completed model training for date 2017-02-04 00:00:00
# [2022-05-13 00:15:18] Completed model training for date 2017-03-06 00:00:00
# [2022-05-13 00:15:22] Completed model training for date 2017-04-05 00:00:00
# CPU times: user 9min 57s, sys: 22.3 s, total: 10min 19s
# Wall time: 5min 33s

# %%
'''
Summary plots of model
'''
dates = pd.Series([x['date'] for x in model_outputs])

# ndcg score
ndcg_trn = pd.Series([x['ndcg_trn'] for x in model_outputs],index=dates)
ndcg_val = pd.Series([x['ndcg_val'] for x in model_outputs],index=dates)
new_plot()
plt.figure(figsize=(12, 4))
ndcg_trn.plot(label='trn')
ndcg_val.plot(label='val')
plt.grid()
plt.legend()
plt.title('NDCG score')
plt.show()

# correlation score
corr_trn = pd.Series([x['corr_trn'] for x in model_outputs],index=dates)
corr_val = pd.Series([x['corr_val'] for x in model_outputs],index=dates)
new_plot()
plt.figure(figsize=(12, 4))
corr_trn.plot(label='trn')
corr_val.plot(label='val')
plt.grid()
plt.legend()
plt.title('Correlation score')
plt.show()


# model predictions
pred_val_out = pd.concat([x['pred_val_out'] for x in model_outputs]).reset_index(drop=True)
new_plot()
plt.figure(figsize=(12, 4))
pred_val_out.groupby('date').size().plot()
plt.grid()
plt.title('Number of predictions made per date')
plt.show()

# feature importance
feat_imp = pd.concat([x['feat_imp'] for x in model_outputs]).groupby('feat').mean().sort_values('imp')
new_plot()
feat_imp.plot.barh(figsize=(12, 4))
plt.title('Feature Importance')
plt.show()

# export
save_pkl(model_outputs, 'model_outputs')
save_pkl(pred_val_out, 'pred_val_out')
